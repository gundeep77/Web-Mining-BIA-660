# %% [markdown]
# <h1><center>HW 2: Scrape Book Reviews</center></h1>

# %% [markdown]
# Choose one of your favorite book at goodreads.com (e.g. for the book "The Midninght Library", the URL is: https://www.goodreads.com/book/show/52578297-the-midnight-library?from_choice=true)

# %% [markdown]
# - Q1. Write a function to scrape all **reviews on the first page**, including,
#     - **reviewer's name** (see (1) in Figure)
#     - **rating** (see (2) in Figure)
#     - **date** (see (3) in Figure)
#     - **review content** (see (4) in Figure. For each review text, need to get the **complete text**, i.e., need to expand the `more` button. Only text is needed, pictures are not needed. (Hint: take a close look at the content of the html file. Do you need Selenium?)
#     - **likes** (see (5) in Figure).
#     - If a field, e.g. rating, is missing, use `None` to indicate it.
# - `Function Input`: book page URL
# - `Function Output`: save all reviews as a DataFrame of columns (`reviewer, rating, date, review, like`). E.g., for the given URL, you can get 30 reviews.
# - 10 points: 1 point for each element, 5 points for overall logic.
# - **Note**: GoodReads occasionaly blocks request. You may get an error that is not due to your codes. You may try to run a couple of times.
#
#
# ![alt text](GoodReads.png "GoodReads")

# %%
import requests
from bs4 import BeautifulSoup  
import pandas as pd
 

def getReviews(page_url):
    
    # enter your codes here
    
    

    return reviews

# %%
# enter your url
page_url = 'https://www.goodreads.com/book/show/52578297-the-midnight-library?from_choice=true'

reviews=getReviews(page_url)
reviews
# Out:
#                                  name           rating          date  \
# 0                            Nataliya        it was ok  Jan 04, 2021
# 1                              Nicole        it was ok  Nov 20, 2020
# 2                     Nilufer Ozmekik   it was amazing  Aug 21, 2020
# 3                            Paromjit   it was amazing  May 28, 2020
# 4                                emma         liked it  Oct 12, 2020
# 5                               Cindy        it was ok  Aug 18, 2021
# 6                               Jayme         liked it  Nov 21, 2020
# 7        Emily (Books with Emily Fox)   it was amazing  Feb 28, 2020
# 8                        Ruby Granger   it was amazing  Feb 25, 2021
# 9                             Emily B         liked it  Sep 20, 2020
# 10                             noelle  really liked it  Dec 31, 2020
# 11                              Gabby   it was amazing  Nov 23, 2020
# 12                                Yun        it was ok  Apr 28, 2021
# 13                      Miranda Reads   it was amazing  Dec 09, 2020
# 14                  Reading_ Tamishly   it was amazing  Aug 22, 2020
# 15                       David Putnam         liked it  Nov 21, 2020
# 16                           AdiTurbo  did not like it  Aug 22, 2020
# 17                           Danielle   it was amazing  Nov 18, 2020
# 18                           Meredith  really liked it  Sep 15, 2020
# 19                       Jenny Lawson   it was amazing  Nov 29, 2020
# 20                            Matthew   it was amazing  Feb 09, 2021
# 21                            jessica  really liked it  Oct 09, 2020
# 22                             chan ☆             None  Jul 06, 2021
# 23                               JanB   it was amazing  Jul 29, 2020
# 24                Dr. Appu Sasidharan   it was amazing  Dec 20, 2020
# 25                              Jenna        it was ok  Oct 13, 2020
# 26                    Susan's Reviews   it was amazing  Jul 15, 2021
# 27                            Marzuqa   it was amazing  Dec 16, 2020
# 28                            Swaroop  really liked it  Sep 03, 2020
# 29  Val ⚓️ Shameless Non-Snowflake ⚓️         liked it  Jan 09, 2021
#
#                                                review     like
# 0   I liked this book until it suddenly decided to...  2498  ·
# 1   Everybody probably knows the premise of this b...   780  ·
# 2   Okay! No more words! This is one of the best s...  2867  ·
# 3   It is no secret that Matt Haig has mental heal...  1629  ·
# 4   Okay. Picture this: you are about to bite into...  1661  ·
# 5   Corny like a Hallmark movie and probably the l...  1931  ·
# 6   Unpopular opinion! In between life and death i...   845  ·
# 7   (4.5?) After loving The Humans, I was very exc...  1552  ·
# 8   okay WOW. This was amazing.I must say that I w...   636  ·
# 9   This was cute and the concept was great but un...  1081  ·
# 10          What a way to end this year of reading! 💘  1326  ·
# 11  “The only way to learn is to live”Fuck, this b...   585  ·
# 12  "That is just me. I add nothing. I am wallowin...   538  ·
# 13  So, first of all, HUGE thank you to goodreads ...   534  ·
# 14  My mind is blown; my soul is lit and I just ca...   516  ·
# 15  This is a quaint little book. A quick read tha...   499  ·
# 16  What a shame - this could have been such a gre...   400  ·
# 17  2021 F.A.B. Bookclub pick # I.❤️. F.A.B. It’s ...   401  ·
# 18  Magical “Let’s be kind to the people in our ow...   376  ·
# 19  I got this before it came out but I was in a b...   336  ·
# 20  This is the ultimate “what if I had done it di...   337  ·
# 21  'if you aim to be something you are not, you w...   291  ·
# 22  are the 10 most popular books of 2021 accordin...   286  ·
# 23  4.5 starsSylvia Plath ‘Between life and death ...   281  ·
# 24  (Throwback Review) A sojourn of a human to the...   263  ·
# 25  Boring!This sort of contemporary fiction is no...   255  ·
# 26  I ABSOLUTELY, TOTALLY, UNEQUIVOCALLY LOVED THI...   251  ·
# 27  “You don’t have to understand life. You just h...   243  ·
# 28  "Between life and death there is a library. An...   237  ·
# 29  3.5 StarsI enjoyed this book, but I feel like ...   223  ·

# %% [markdown]
# - Q2 (Bonus). Modify the function you defined in Q1 to scrape **reviews on all the pages** for your url. Since a book may have multiple pages, use the **next** button at the end of each page (shown in the picture) to navigate to the next page. Continue scraping all the pages until the last page. `Please don't hardcode the pages in the URL because the number of pages varies by book`. (3 points. If URL is hardcoded, -2).
#
# ![alt text](GoodReads_bonus.png "GoodReads_bonus")

# %%
def getReviews_2(page_url):

    reviews=[]

    # enter your codes here
    
    
    

    return reviews

# %%
# enter your url
page_url = 'https://www.goodreads.com/book/show/52578297-the-midnight-library?from_choice=true'

reviews=getReviews_2(page_url)
reviews
# Out:
# https://www.goodreads.com/book/show/52578297-the-midnight-library?from_choice=true&amp;hide_last_page=true&amp;language_code=en&amp;page=2
# https://www.goodreads.com/book/show/52578297-the-midnight-library?from_choice=true&amp;hide_last_page=true&amp;language_code=en&amp;page=3
# https://www.goodreads.com/book/show/52578297-the-midnight-library?from_choice=true&amp;hide_last_page=true&amp;language_code=en&amp;page=4
# https://www.goodreads.com/book/show/52578297-the-midnight-library?from_choice=true&amp;hide_last_page=true&amp;language_code=en&amp;page=5
# https://www.goodreads.com/book/show/52578297-the-midnight-library?from_choice=true&amp;hide_last_page=true&amp;language_code=en&amp;page=6
# https://www.goodreads.com/book/show/52578297-the-midnight-library?from_choice=true&amp;hide_last_page=true&amp;language_code=en&amp;page=7
# https://www.goodreads.com/book/show/52578297-the-midnight-library?from_choice=true&amp;hide_last_page=true&amp;language_code=en&amp;page=8
# https://www.goodreads.com/book/show/52578297-the-midnight-library?from_choice=true&amp;hide_last_page=true&amp;language_code=en&amp;page=9
# https://www.goodreads.com/book/show/52578297-the-midnight-library?from_choice=true&amp;hide_last_page=true&amp;language_code=en&amp;page=10
# https://www.goodreads.com/book/show/52578297-the-midnight-library?from_choice=true&amp;hide_last_page=true&amp;language_code=en&amp;page=11
#                    name           rating          date  \
# 0              Nataliya        it was ok  Jan 04, 2021
# 1                Nicole        it was ok  Nov 20, 2020
# 2       Nilufer Ozmekik   it was amazing  Aug 21, 2020
# 3              Paromjit   it was amazing  May 28, 2020
# 4                  emma         liked it  Oct 12, 2020
# ..                  ...              ...           ...
# 295              Herbie  really liked it  Nov 29, 2020
# 296                 2bb        it was ok  Dec 21, 2020
# 297  Kate (GirlReading)  really liked it  Jun 16, 2021
# 298                Beth  really liked it  Jun 10, 2021
# 299       Prabhjot Kaur   it was amazing  Mar 19, 2021
#
#                                                 review     like
# 0    I liked this book until it suddenly decided to...  2499  ·
# 1    Everybody probably knows the premise of this b...   780  ·
# 2    Okay! No more words! This is one of the best s...  2867  ·
# 3    It is no secret that Matt Haig has mental heal...  1629  ·
# 4    Okay. Picture this: you are about to bite into...  1661  ·
# ..                                                 ...      ...
# 295  This book is perfect. An absolute delight to r...    22  ·
# 296  Great concept and a fast read, but lacks a bit...    22  ·
# 297  it’s lucky this book is so utterly fantastic b...    21  ·
# 298  I plucked this off a supermarket shelf because...    22  ·
# 299  Nora Seed hasn't had the best week, in fact le...    21  ·
#
# [300 rows x 5 columns]
